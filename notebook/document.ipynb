# %% [markdown]
# ### DATA INGESTION

# %%
### Document Structure 
from langchain_core.documents import Document

# %%
doc=Document(
    page_content = "this is the main text content i am using to create RAG",
    metadata = {
        "source":"example.txt",
        "pages" : 1 ,
        "author":"Aditya Pawar",
        "date_created":"23-04-2026" 
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Aditya Pawar', 'date_created': '23-04-2026'}, page_content='this is the main text content i am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
### from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
import os

os.makedirs("../data/pdf", exist_ok=True)
print("Folder created!")

### add any pdf in data--> pdf folder
# Out:
# Folder created!

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-23T20:57:12+05:30', 'source': '..\\data\\pdf\\AdityaPawar_CV.pdf', 'file_path': '..\\data\\pdf\\AdityaPawar_CV.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'adityapawar147@gmail.com;adityabpawar.work@gmail.com', 'subject': '', 'keywords': '', 'moddate': '2026-04-23T20:57:12+05:30', 'trapped': '', 'modDate': "D:20260423205712+05'30'", 'creationDate': "D:20260423205712+05'30'", 'page': 0}, page_content='ADITYA PAWAR \n+91 9137943441 | Mumbai, India | adityabpawar.work@gmail.com | LinkedIn | GitHub \n  \nQualified GATE 2026 (CS & IT) with an ALL-INDIA RANK of 22,192 out of 211,020 Candidates  \n(89.5 percentile). GATE SCORECARD. Undergraduate student pursuing BE in Artificial Intelligence & \nData Science with strong foundations in Machine Learning, DBMS, and core CS concepts Skilled in \nPython, SQL, and building data-driven applications, with hands on experience in real-world projects \n \nINTERNSHIPS \n \nAIML Intern – IBM Skills Build                                                                                                                    06/2024 – 07/2024 \n• \nDeveloped and deployed NLP-based chatbots, trained on 2,000+ sample conversations to simulate customer interaction. \n• \nOptimized ML model parameters, improving classification accuracy from ~70% to 92% & Made AI based solutions \n• \nGained hands-on experience in deploying models and testing performance in real-world conditions. \n \nData Analytics Intern – IBM Skills Build                                     \n \n \n \n            07/2024 - 08/2024 \n• \nAnalysed ~5,000 structured and unstructured records using Python, SQL, and Excel to derive 10+ actionable insights. \n• \nCleaned and transformed raw datasets using Pandas and SQL, reducing processing effort by 25%. \n• \nCreated 4 interactive dashboards with Power BI & Tableau to visualize KPIs and trends for decision-making. \n \nYASHAM Foundation NGO – Student Mentor                                                                                           05/2025 - Present \n• \nProviding Mentorship & Guidance to over 100+ students in the field of Artificial Intelligence, Data Science & Computer Science \n \n \nEDUCATION \n \nUniversity of Mumbai:                                                                                                                                  Mumbai, IN | 2022 – Present \nBE in Artificial Intelligence & Data Science: CGPA: 7.22 - Vasant Dada Patil College of Engineering  \n \nHSC Board: 73.67% - Lakshya Prep High School & Jr. College                                                                         Mumbai, IN | 2020 - 2022 \nSSC Board: 84.20% - St. Joseph’s High School \n \n \n \n \n \n               Mumbai, IN | 2008 - 2020 \n \n \nPROJECTS \n       \nVEDSHREE – Ayurvedic Cloud-Based ERP System                                                                                05/2025 – 05/2026 \nSPONSORED PROJECT: Sponsorship Letter | ( Live Deployment at: https://vedshree-indol.vercel.app/ )             \nTechnologies: Neon DB (Cloud PostgreSQL), Next.js, React, Tailwind CSS, RESTful APIs \n• \nBuilt and hosted a cloud-based ERP system integrating 4+ modules (Doctor Portal, Admin Portal, Patient Portal, Inventory \nManagement) into a unified platform for streamlined operations. \n• \nArchitected and managed a centralized PostgreSQL database (Neon DB) handling 2,000+ medicine inventory records and \n500+ customer profiles, along with admin, employee, and doctor data. \n• \nImplemented inventory management with automated low-stock alerts, improving operational efficiency and reducing manual \ntracking efforts. \n• \nDesigned responsive UI using Next.js, React, and Tailwind CSS, and integrated RESTful APIs to enable seamless data flow \nacross modules. \n \nCustomer Behaviour Analytics                                                   ...
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-04-23T20:57:12+05:30', 'source': '..\\data\\pdf\\AdityaPawar_CV.pdf', 'file_path': '..\\data\\pdf\\AdityaPawar_CV.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'adityapawar147@gmail.com;adityabpawar.work@gmail.com', 'subject': '', 'keywords': '', 'moddate': '2026-04-23T20:57:12+05:30', 'trapped': '', 'modDate': "D:20260423205712+05'30'", 'creationDate': "D:20260423205712+05'30'", 'page': 1}, page_content='SKILLS \n \n• \nProgramming Languages: Python, SQL, Neon DB, C++, C, Dart, JavaScript, HTML, CSS \n• \nFrameworks & Libraries for Data Science & Machine Learning: NumPy, Pandas, Matplotlib, Seaborn, OpenCV, Sci-Kit-\nLearn, TensorFlow, PyTorch, Lang Chain, Lang Graph Web Scraping \n• \nMachine Learning & AI: Supervised (Linear Regression, Logistic Regression, Decision Trees, Random Forest, SVM, Naive \nBayes), Unsupervised (K-Means, Hierarchical Clustering, DBSCAN), Feature Engineering, Model Selection & Hyperparameter \nTuning, Ensemble Learning, Model Evaluation (Cross-Validation, Confusion Matrix, Accuracy, Precision, Recall, F1-Score, \nROC-AUC), Deep Learning (ANN, CNN, RNN, Transformers, GANs, VAEs, Transfer Learning), Natural Language Processing \n(Text Preprocessing, Tokenization, Embeddings, NER, Sentiment Analysis), Generative AI  Computer Vision (Image \nClassification, Object Detection, OpenCV), Statistical Analysis, Time Series Basics \n• \nSQL: Joins, Subqueries, Window Functions, Aggregations, Query Optimization, Indexing, Transactions (ACID), Triggers, \nStored Procedures \n• \nPower BI: Dashboard Development, Data Modelling, Data Cleaning & Transformation Power Query, DAX, Interactive \nVisualizations, KPI Tracking, Data Integration (SQL, Excel, APIs), Data Storytelling, Business Intelligence, ETL Pipelines \n• \nData Engineering Tools: MySQL Workbench, Jupyter Notebook, ETL Pipelines, PyoDB  \n• \nTools for Data Visualization & Version Control: Excel, PowerBI, Tableau, Amazon Web Services (AWS), GitHub, GIT \n• \nGenerative AI & Prompt Engineering: ChatGPT, n8n, Hugging Face, Claude, Gemini, Copilot \n• \nDevelopment: Flutter using Dart, React, Next.js, Node.js, Express.js, Server.js, Ethers  \n• \nSoft Skills: Communication, Leadership, Team Collaboration, Public Speaking, Mentorship, Negotiation, Sponsorship \nNegotiation, Conflict Resolution, Data Storytelling \n \nHACKATHONS \n \n• \n1st Place (3x): Avenir Analytics Club Hackathons (2024, 2025), ICARUS Hackathon – RGIT (2025) \n• \n2nd Place: Codefolio, F.A.C.E – SPIT (2025) \n \nCERTIFICATES \n \n• \nAI & Data Science: Professional Certification Program (iHUB DivyaSampark, IIT Roorkee – Ongoing) \n• \nCloud: AWS Academy Graduate – Cloud Foundations | Microsoft Azure AI Essentials \n• \nData & Analytics: Microsoft Power BI Data Analyst | Deloitte Data Analytics Job Simulation \n• \nProgramming: Python (Intellipaat) | SQL (Intellipaat) | Advanced Python for Data Science \n• \nDevelopment: Flutter Development Bootcamp (Dart) | Full-Stack Web Development')]

# %%
type(pdf_documents[0])
